# %%
a=100
a
# Out:
# 100

# %%
a=10
b=20
a+b
# Out:
# 30

# %% [markdown]
# today im learning python
# im in code mode
# i need to change to markdown mode
# select the perticular cell first
# the in the top

# %% [markdown]
# - i like python "for git hub practice i write this"
# - esc+m code mode to markdown mode
# - esc+y markdown mode to code mode
# - shift+enter
# - square brackets indicates code mode
# - when we are in markdown mode square brackets will not appear

# %% [markdown]
# ## python
# - when we use symbol in code it behave as comment
# - when we use the same in markdown mode itv behaves as title

# %% [markdown]
# <img id="dimg_tJgaZ5_fKtzh2roP387PkQc_287" src="data:image/jpeg;base64,..." class="YQ4gaf" height="160" style="object-position:55% 40%" width="314" alt="future programming language ..." data-csiid="tJgaZ5_fKtzh2roP387PkQc_20" data-atf="1">

# %% [markdown]
# <img id="dimg_tJgaZ5_fKtzh2roP387PkQc_260" src="data:image/jpeg;base64,..." class="YQ4gaf" height="194" style="object-position:82% 50%" width="259" alt="Python: find out the best courses ..." data-csiid="tJgaZ5_fKtzh2roP387PkQc_48" data-atf="4">

# %% [markdown]
# **for insert image**
#
# - CTRL+A
# - CTRL=C
# - CTRL==V
# - esc=m
# - shift+enter

# %% [markdown]
# <img src="https://contentstatic.techgig.com/thumb/msid-101591195,width-800,resizemode-4/Why-is-python-one-of-the-best-programming-languages.jpg?9070" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 800px; height: 168px; margin: 0px; width: 351px;" alt="Why is python one of the best programming languages? | TechGig" jsname="kn3ccd" aria-hidden="false">

# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQmEuMP22nw0v14kH8aDXMzvAul8j0CT5BJAg&amp;s" class="sFlh5c FyHeAf" alt="500+ Best Tiger Images · 100% Free Download · Pexels Stock ..." jsname="JuXqh" style="max-width: 3532px; width: 351px; height: 230px; margin: 0px;" data-ilt="1730223590548">
